# %%
import pandas as pd
df1 = pd.read_csv('./Data/Train1.csv')
df1.columns
# Out:
# Index(['passenger_id', 'fare', 'cabin', 'embarked', 'home.dest', 'survived'], dtype='object')

# %%
df2 = pd.read_csv('./Data/Train2.csv')
df2.columns
# Out:
# Index(['passenger_id', 'pclass', 'name', 'sex', 'age', 'sibsp', 'parch',
#        'ticket'],
#       dtype='object')

# %%
df = df1.merge(df2, on = 'passenger_id', how = 'inner')
print(df.columns)
print(df.shape)
# Out:
# Index(['passenger_id', 'fare', 'cabin', 'embarked', 'home.dest', 'survived',
#        'pclass', 'name', 'sex', 'age', 'sibsp', 'parch', 'ticket'],
#       dtype='object')
# (917, 13)

# %%
dfhold = pd.read_csv('./Data/Hold.csv')
dfhold.columns
print(dfhold.shape)
# Out:
# (393, 13)

# %%
dfinference1 = pd.read_csv('./Data/Day2_inference1.csv')
print(dfinference1.columns)
print(dfinference1.shape)
# Out:
# Index(['passenger_id', 'fare', 'cabin', 'embarked', 'home.dest', 'survived'], dtype='object')
# (314, 6)

# %%
dfinference2 = pd.read_csv('./Data/Day2_inference2.csv')
print(dfinference2.columns)
print(dfinference2.shape)
# Out:
# Index(['passenger_id', 'pclass', 'name', 'sex', 'age', 'sibsp', 'parch',
#        'ticket'],
#       dtype='object')
# (314, 8)

# %%
dfinference = dfinference1.merge(dfinference2, on = 'passenger_id', how = 'inner')
print(dfinference.columns)
print(dfinference.shape)
# Out:
# Index(['passenger_id', 'fare', 'cabin', 'embarked', 'home.dest', 'survived',
#        'pclass', 'name', 'sex', 'age', 'sibsp', 'parch', 'ticket'],
#       dtype='object')
# (314, 13)

# %%
print(dfinference.columns == df.columns)
# Out:
# [ True  True  True  True  True  True  True  True  True  True  True  True
#   True]

# %%
l1 = set(dfinference.columns)  
l2 = set(df.columns)  
  
if l1 == l2:  
    print("The a and b are equal")  
else:  
    print("The a and b are not equal")
# Out:
# The a and b are equal
